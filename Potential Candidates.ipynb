# %% [markdown]
# ### Overview
# A company is trying to minimize the manual efforts invested in screening the candidates that they seem to be a good fit for the job description.
#
# And in order to do that we need 2 phases as shown below:
#
# #### Phase 1 : Rank the Candidates
#
# The goal of phase one is to build a model for predicting how to fit the candidate for a particular role. Keywords to be used for search are 'Aspiring human resources' or 'seeking human resources'. The model's output indicates how fit the candidate is for the role? (numeric, probability between 0-1)
#
#
# #### Phase 2 : Rerank when a candidate is starred
# The goal of phase two is to let Human resources individual/end-user using this model provide priority to any individual who they think might be good for the role but was ranked lower by the model. Then based on the inputs provided, the model will re-rank the candidates keeping the human inputs into consideration.
#
# #### Data Description:
#
# The data comes from our sourcing efforts. We removed any field that could directly reveal personal details and gave a unique identifier for each candidate.
#
# Attributes:
# id : unique identifier for candidate (numeric)
#
# job_title : job title for candidate (text)
#
# location : geographical location for candidate (text)
#
# connections: number of connections candidate has, 500+ means over 500 (text)

# %% [markdown]
# ### Import Libraries:

# %%
# !pip install gensim==4.2.0

# %%
# !pip install sentence_transformers==2.2.2

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.spatial.distance import cosine
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer


# random
import random
# pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ### Exploratory Data Analysis:

# %% [markdown]
# #### Load data:

# %%
df=pd.read_csv("potential-talents - Aspiring human resources - seeking human resources.csv").set_index('id')

# %%
df.head()
# Out:
#                                             job_title  \
# id
# 1   2019 C.T. Bauer College of Business Graduate (...
# 2   Native English Teacher at EPIK (English Progra...
# 3               Aspiring Human Resources Professional
# 4              People Development Coordinator at Ryan
# 5     Advisory Board Member at Celal Bayar University
#
#                                location connection  fit
# id
# 1                        Houston, Texas         85  NaN
# 2                                Kanada      500+   NaN
# 3   Raleigh-Durham, North Carolina Area         44  NaN
# 4                         Denton, Texas      500+   NaN
# 5                        İzmir, Türkiye      500+   NaN

# %%
df.shape
# Out:
# (104, 4)

# %% [markdown]
# ### Preprocessing:
# #### Data Cleaning:

# %%
print("\nData Types:")
print(df.dtypes)
print("\nChecking missing values in relevant columns:")
print( "Count of missing values in job title" , df['job_title'].isnull().sum())
print( "Count of missing values in location" , df['location'].isnull().sum())
print( "Count of missing values in connection" , df['connection'].isnull().sum())
print( "Count of missing values in fit" , df['fit'].isnull().sum())
# Out:
# Data Types:
# job_title      object
# location       object
# connection     object
# fit           float64
# dtype: object
#
# Checking missing values in relevant columns:
# Count of missing values in job title 0
# Count of missing values in location 0
# Count of missing values in connection 0
# Count of missing values in fit 104

# %%
df.connection.value_counts()
# Out:
# 500+     44
# 85        7
# 61        7
# 44        6
# 1         5
# 2         4
# 57        2
# 7         2
# 4         2
# 390       2
# 39        1
# 49        1
# 18        1
# 50        1
# 268       1
# 48        1
# 40        1
# 64        1
# 52        1
# 19        1
# 5         1
# 155       1
# 174       1
# 349       1
# 82        1
# 71        1
# 16        1
# 409       1
# 212       1
# 103       1
# 455       1
# 9         1
# 415       1
# Name: connection, dtype: int64

# %% [markdown]
# Turn connections into a numeric field for potential use:

# %%
df.connection=df.connection.str.replace("500+ ","500",regex=False)
df.connection=df.connection.astype(int)

# %%
df.dtypes
# Out:
# job_title      object
# location       object
# connection      int64
# fit           float64
# dtype: object

# %% [markdown]
# Checking how many duplicate entries we have:

# %%
df_dup = df.duplicated().sum()

df_dup
# Out:
# 51

# %% [markdown]
# Dropping duplicates:

# %%
Drop_dup = df.drop_duplicates()
print("Shape of non-duplicated dataframe:", Drop_dup.shape)
# Out:
# Shape of non-duplicated dataframe: (53, 4)

# %%
Drop_dup.head()
# Out:
#                                             job_title  \
# id
# 1   2019 C.T. Bauer College of Business Graduate (...
# 2   Native English Teacher at EPIK (English Progra...
# 3               Aspiring Human Resources Professional
# 4              People Development Coordinator at Ryan
# 5     Advisory Board Member at Celal Bayar University
#
#                                location  connection  fit
# id
# 1                        Houston, Texas          85  NaN
# 2                                Kanada         500  NaN
# 3   Raleigh-Durham, North Carolina Area          44  NaN
# 4                         Denton, Texas         500  NaN
# 5                        İzmir, Türkiye         500  NaN

# %% [markdown]
# #### Data cleaning:

# %%
import nltk

nltk.download('all-corpora')

# %% [markdown]
# In order to clean data we are going through the steps below:
#
# * Remove stop words
# * Remove special characters and punctuation.
# * Apply lemmatization.
# * The text should be written all in lower case
# * Replace all of the HR by human resources As the Keywords are: Aspiring human resources or seeking human resources.

# %%
cleanData = Drop_dup.copy()
cleanData['cleanJobTitle'] = ""

stopWords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

for i in Drop_dup.index :
    # Fetch appropriate jobTitle
    jobTitle = Drop_dup['job_title'][i]
    tempString = ''
    # Replace HR with human resources
    tempString = jobTitle.replace("HR", " human resources ")
    # Make word all lower case
    tempString = tempString.lower()
    
    # Initialize empty wordList array for jobTitle
    wordList = []
    
    for token in tempString.split() :
        # Initialize variable
        word = ""
        # Remove all characters except letters and numbers
        temp = list([e for e in token if e.isalnum()])
        # Join letters from temp list back together
        word = "".join(temp)
        
        # Lemmatize word
        word = lemmatizer.lemmatize(word)
        
        if word not in stopWords :
            wordList.append(word)
    
    # Join tokens from wordList array with spaces inbetween
    cleanJobTitle = " ".join(wordList)
    
    cleanData['cleanJobTitle'][i] = cleanJobTitle

# %%
cleanData.head()
# Out:
#                                             job_title  \
# id
# 1   2019 C.T. Bauer College of Business Graduate (...
# 2   Native English Teacher at EPIK (English Progra...
# 3               Aspiring Human Resources Professional
# 4              People Development Coordinator at Ryan
# 5     Advisory Board Member at Celal Bayar University
#
#                                location  connection  fit  \
# id
# 1                        Houston, Texas          85  NaN
# 2                                Kanada         500  NaN
# 3   Raleigh-Durham, North Carolina Area          44  NaN
# 4                         Denton, Texas         500  NaN
# 5                        İzmir, Türkiye         500  NaN
#
#                                         cleanJobTitle
# id
# 1   2019 ct bauer college business graduate magna ...
# 2   native english teacher epik english program korea
# 3                aspiring human resource professional
# 4                 people development coordinator ryan
# 5        advisory board member celal bayar university

# %% [markdown]
# ### Rank the Candidates:
#
# We'll implement machine learning algorithms to rank the job titles listed in the dataset with respect to the key phrases:
#
# * Aspiring human resources
# * Seeking human resources

# %% [markdown]
# ### FuzzyWuzzy:
#
# FuzzyWuzzy has four score options to find the Levenshtein distance between two strings.
# ratio simularity, partial ratio simularity, token_sort_ratio, token set ratio.
#
# I believe that the token sort ratio and the token set ratio are more suitable for this dataset which might have mixed words order and duplicated words.

# %%
# key phrases:
phrase_1="aspiring human resources"
phrase_2="seeking human resources"
phrases_list=[phrase_1,phrase_2]

# %% [markdown]
# #### Token Sort Ratio:
# The token sort ratio scorer finds the Levenshtein distance and returns the similarity percentage.

# %%
# !pip install fuzzywuzzy==0.18.0

# %%
from fuzzywuzzy import process, fuzz

# %%
#Create tuples of phrases_list , matched job title, and the score
score_sort = [(x,) + i
             for x in phrases_list 
             for i in process.extract(x, cleanData.cleanJobTitle, scorer=fuzz.token_sort_ratio)]

# %%
#Create dataframe from the tuples
similarity_sort = pd.DataFrame(score_sort, columns=['phrases','cleanJobTitle','score_sort','ignore'])
similarity_sort.drop('ignore',axis=1,inplace=True)
similarity_sort.head()
# Out:
#                     phrases                         cleanJobTitle  score_sort
# 0  aspiring human resources    aspiring human resource specialist          83
# 1  aspiring human resources  aspiring human resource professional          77
# 2  aspiring human resources  aspiring human resource professional          77
# 3  aspiring human resources            director human resource ey          68
# 4  aspiring human resources     human resource generalist schwans          63

# %% [markdown]
# #### Token Set Ratio:

# %%
score_set = [(x,) + i
             for x in phrases_list 
             for i in process.extract(x, cleanData.cleanJobTitle, scorer=fuzz.token_set_ratio)]

# %%
similarity_set = pd.DataFrame(score_set, columns=['phrases','cleanJobTitle','score_set','ignore'])
similarity_set.drop('ignore',axis=1,inplace=True)
similarity_set.head()
# Out:
#                     phrases  \
# 0  aspiring human resources
# 1  aspiring human resources
# 2  aspiring human resources
# 3  aspiring human resources
# 4  aspiring human resources
#
#                                        cleanJobTitle  score_set
# 0                 aspiring human resource specialist         83
# 1               aspiring human resource professional         77
# 2               aspiring human resource professional         77
# 3  2019 ct bauer college business graduate magna ...         74
# 4  student humber college aspiring human resource...         74

# %% [markdown]
# ### Word Embedding Techniques:
# In order to apply these Techniques we need to vectorize the job titles, vectorize the query strings and use cosine similarity to see how closely they match.

# %% [markdown]
# #### TF-IDF cosine similarity:

# %%
#Convert search phrase into a vector
tfv=TfidfVectorizer()
vects=tfv.fit_transform(cleanData.cleanJobTitle)
#Get the appropriate vectors 
tf_phrase=tfv.transform(phrases_list)

# %%
# Calcualte Tfidf cosine similarity and add it to the dataframe
cleanData["tfidf_sim_1"]=cosine_similarity(vects,tf_phrase)[:,0]
cleanData["tfidf_sim_2"]=cosine_similarity(vects,tf_phrase)[:,1]
cleanData['tfidf_sim'] = ((cleanData["tfidf_sim_1"] + cleanData["tfidf_sim_2"])/2)

# %% [markdown]
# We'll check the top 5 matching title job rows with the 2 phrases.

# %%
cleanData.sort_values("tfidf_sim",ascending=False).head()
# Out:
#                                             job_title  \
# id
# 73  Aspiring Human Resources Manager, seeking inte...
# 3               Aspiring Human Resources Professional
# 97              Aspiring Human Resources Professional
# 27  Aspiring Human Resources Management student se...
# 99                   Seeking Human Resources Position
#
#                                location  connection  fit  \
# id
# 73                  Houston, Texas Area           7  NaN
# 3   Raleigh-Durham, North Carolina Area          44  NaN
# 97                 Kokomo, Indiana Area          71  NaN
# 27                  Houston, Texas Area         500  NaN
# 99               Las Vegas, Nevada Area          48  NaN
#
#                                         cleanJobTitle  tfidf_sim_1  \
# id
# 73  aspiring human resource manager seeking intern...     0.481429
# 3                aspiring human resource professional     0.680582
# 97               aspiring human resource professional     0.680582
# 27  aspiring human resource management student see...     0.384157
# 99                    seeking human resource position     0.153506
#
#     tfidf_sim_2  tfidf_sim
# id
# 73     0.503455   0.492442
# 3      0.166562   0.423572
# 97     0.166562   0.423572
# 27     0.413559   0.398858
# 99     0.627236   0.390371

# %% [markdown]
# The 5 less matching title job rows with the 2 phrases:

# %%
cleanData.sort_values("tfidf_sim",ascending=False).tail()
# Out:
#                                              job_title  \
# id
# 87   Bachelor of Science in Biology from Victoria U...
# 86   Information Systems Specialist and Programmer ...
# 85   RRP Brand Portfolio Executive at JTI (Japan To...
# 80            Junior MES Engineer| Information Systems
# 104   Director Of Administration at Excellence Logging
#
#                               location  connection  fit  \
# id
# 87                 Baltimore, Maryland          40  NaN
# 86              Gaithersburg, Maryland           4  NaN
# 85           Greater Philadelphia Area         500  NaN
# 80   Myrtle Beach, South Carolina Area          52  NaN
# 104                        Katy, Texas         500  NaN
#
#                                          cleanJobTitle  tfidf_sim_1  \
# id
# 87   bachelor science biology victoria university w...          0.0
# 86   information system specialist programmer love ...          0.0
# 85   rrp brand portfolio executive jti japan tobacc...          0.0
# 80                  junior engineer information system          0.0
# 104         director administration excellence logging          0.0
#
#      tfidf_sim_2  tfidf_sim
# id
# 87           0.0        0.0
# 86           0.0        0.0
# 85           0.0        0.0
# 80           0.0        0.0
# 104          0.0        0.0

# %% [markdown]
# #### BERT:

# %%
# !pip install sentence_transformers

# %% [markdown]
# Build BERT_base model:

# %%
bert_model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# Downloading: 100%|██████████| 391/391 [00:00<00:00, 696kB/s]
# Downloading: 100%|██████████| 190/190 [00:00<00:00, 382kB/s]
# Downloading: 100%|██████████| 3.95k/3.95k [00:00<00:00, 6.87MB/s]
# Downloading: 100%|██████████| 2.00/2.00 [00:00<00:00, 3.94kB/s]
# Downloading: 100%|██████████| 625/625 [00:00<00:00, 1.02MB/s]
# Downloading: 100%|██████████| 122/122 [00:00<00:00, 227kB/s]
# Downloading: 100%|██████████| 438M/438M [00:04<00:00, 109MB/s]
# Downloading: 100%|██████████| 53.0/53.0 [00:00<00:00, 72.5kB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 167kB/s]
# Downloading: 100%|██████████| 466k/466k [00:00<00:00, 105MB/s]
# Downloading: 100%|██████████| 399/399 [00:00<00:00, 870kB/s]
# Downloading: 100%|██████████| 232k/232k [00:00<00:00, 83.0MB/s]
# Downloading: 100%|██████████| 229/229 [00:00<00:00, 394kB/s]

# %% [markdown]
# Convert job titles into BERT embedded vectors:

# %%
bert_job_title_embeddings = bert_model.encode(list(cleanData.cleanJobTitle))
bert_job_title_embeddings.shape
# Out:
# (53, 768)

# %% [markdown]
# Convert search phrase into a BERT embedded vector:

# %%
bert_search_phrase_embedding = bert_model.encode(phrases_list[0])

bert_search_phrase_embedding.shape
# Out:
# (768,)

# %% [markdown]
# Calculate cosine similarity between job title and search phrase vectors:

# %%
bert_cosine_similarity = []
for i in range(len(cleanData)):
    cos_sim = 1 - cosine(bert_job_title_embeddings[i], bert_search_phrase_embedding)
    bert_cosine_similarity.append(cos_sim)
    
# Add BERT_cosine_similarity column in the pt dataframe
cleanData['BERT_model_fitt_score'] = bert_cosine_similarity

# %%
cleanData[['job_title', 'cleanJobTitle','tfidf_sim', 'BERT_model_fitt_score']].sort_values(by ='BERT_model_fitt_score', ascending = False).head()
# Out:
#                                             job_title  \
# id
# 6                 Aspiring Human Resources Specialist
# 3               Aspiring Human Resources Professional
# 97              Aspiring Human Resources Professional
# 82  Aspiring Human Resources Professional | An ene...
# 99                   Seeking Human Resources Position
#
#                                         cleanJobTitle  tfidf_sim  \
# id
# 6                  aspiring human resource specialist   0.372814
# 3                aspiring human resource professional   0.423572
# 97               aspiring human resource professional   0.423572
# 82  aspiring human resource professional  energeti...   0.206308
# 99                    seeking human resource position   0.390371
#
#     BERT_model_fitt_score
# id
# 6                0.950305
# 3                0.930828
# 97               0.930828
# 82               0.854400
# 99               0.837419

# %%
cleanData[['job_title', 'cleanJobTitle','tfidf_sim', 'BERT_model_fitt_score']].sort_values(by ='BERT_model_fitt_score', ascending = False).tail()
# Out:
#                                             job_title  \
# id
# 91       Lead Official at Western Illinois University
# 85  RRP Brand Portfolio Executive at JTI (Japan To...
# 96  Student at Indiana University Kokomo - Busines...
# 93  Admissions Representative at Community medical...
# 87  Bachelor of Science in Biology from Victoria U...
#
#                                         cleanJobTitle  tfidf_sim  \
# id
# 91          lead official western illinois university        0.0
# 85  rrp brand portfolio executive jti japan tobacc...        0.0
# 96  student indiana university kokomo  business ma...        0.0
# 93  admission representative community medical cen...        0.0
# 87  bachelor science biology victoria university w...        0.0
#
#     BERT_model_fitt_score
# id
# 91               0.367655
# 85               0.270093
# 96               0.252365
# 93               0.192242
# 87               0.139689

# %% [markdown]
# BERT is the best performing model, As it gives us a high score for the top titles and the low ones as well.

# %% [markdown]
# ### Learning to Rank (LTR):

# %% [markdown]
# We are going to Re-rank our job titles when a candidate is starred manually.
#
# Working of RankNet
#
# * A neural network with Linear, Dropout and activation layers is built which takes job title as input and returns a prediction.
# * Two random samples from the job titles are selected and their output is computed separately using forward propagation.
# * The cost, which is the difference between the two outputs is calculated and appropriate loss is calculated.
# * The loss is back-propogated to learn the selected example.

# %%
Data = cleanData[['cleanJobTitle','location', 'connection','fit','BERT_model_fitt_score']]
Data.sort_values(by ='BERT_model_fitt_score', ascending = False).head()
# Out:
#                                         cleanJobTitle  \
# id
# 6                  aspiring human resource specialist
# 3                aspiring human resource professional
# 97               aspiring human resource professional
# 82  aspiring human resource professional  energeti...
# 99                    seeking human resource position
#
#                                location  connection  fit  \
# id
# 6            Greater New York City Area           1  NaN
# 3   Raleigh-Durham, North Carolina Area          44  NaN
# 97                 Kokomo, Indiana Area          71  NaN
# 82                   Austin, Texas Area         174  NaN
# 99               Las Vegas, Nevada Area          48  NaN
#
#     BERT_model_fitt_score
# id
# 6                0.950305
# 3                0.930828
# 97               0.930828
# 82               0.854400
# 99               0.837419

# %%
star_candidate = input("Do you want to star any candidates? Enter 'Yes' or 'No': ")

starred = []
if star_candidate.lower() == 'yes':
    starred = [int(item) for item in input("Enter ids of candidates you want to star (separated by space) : ").split()]

# %%
Data['starredScore'] = Data['BERT_model_fitt_score']

for id_num in starred:
    Data['starredScore'][id]=1

Data.head()
# Out:
#                                         cleanJobTitle  \
# id
# 1   2019 ct bauer college business graduate magna ...
# 2   native english teacher epik english program korea
# 3                aspiring human resource professional
# 4                 people development coordinator ryan
# 5        advisory board member celal bayar university
#
#                                location  connection  fit  \
# id
# 1                        Houston, Texas          85  NaN
# 2                                Kanada         500  NaN
# 3   Raleigh-Durham, North Carolina Area          44  NaN
# 4                         Denton, Texas         500  NaN
# 5                        İzmir, Türkiye         500  NaN
#
#     BERT_model_fitt_score  starredScore
# id
# 1                0.578465      0.578465
# 2                0.411404      0.411404
# 3                0.930828      0.930828
# 4                0.755497      0.755497
# 5                0.475463      0.475463

# %%
# Set seed for reproducability
random.seed(123)

# Build a Deep Learning RankNet class
class RankNet(nn.Module):
    
    def __init__(self, num_feature):
        super(RankNet, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(num_feature, 512),         # Linear layer
            nn.Dropout(0.5),                     # Regularization
            nn.LeakyReLU(0.2, inplace=True),     # Activation function
            nn.Linear(512, 256),
            nn.Dropout(0.5),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            nn.Sigmoid()                         # output between 0 and 1
        )
        self.output_sig = nn.Sigmoid()

    def forward(self, input_1, input_2):
        s1 = self.model(input_1)
        s2 = self.model(input_2)
        out = self.output_sig(s1-s2)
        return out
    
    def predict(self, input_):
        s = self.model(input_)
        return s

# %% [markdown]
# Generate data:

# %%
random_row_1 = Data.sample(n = 5000, replace = True)
random_row_2 = Data.sample(n = 5000, replace = True)

# %% [markdown]
# Get list of job titles for each data generated:

# %%
job_title_list_ranknet1 = list(random_row_1['cleanJobTitle'])
job_title_list_ranknet2 = list(random_row_2['cleanJobTitle'])

# %%
doc1 = bert_model.encode(job_title_list_ranknet1)
doc2 = bert_model.encode(job_title_list_ranknet2)
doc1 = torch.from_numpy(doc1).float()
doc2 = torch.from_numpy(doc2).float()

# %% [markdown]
# Generate ground truth for RankNet model:

# %%
y_1 = list(random_row_1['starredScore'])
y_2 = list(random_row_2['starredScore'])
#Ground truth for ranknet: output is 1 if first entry has higher value, 0 if second entry is higher, 0.5 if equal
y = torch.tensor([1.0 if y1_i>y2_i else 0.5 if y1_i==y2_i else 0.0 for y1_i, y2_i in zip(y_1, y_2)]).float()

y = y.unsqueeze(1)

# %%
y.shape
# Out:
# torch.Size([5000, 1])

# %% [markdown]
# Initialize an instance of RankNet model and define loss function:

# %%
rank_model = RankNet(num_feature = 768)     
optimizer = torch.optim.SGD(rank_model.parameters(), lr = 0.01, momentum = 0.9)        
loss_fun = torch.nn.BCELoss()

# %% [markdown]
# Loss optimization by running RankNet model through various iterations:

# %%
epoch = 1000
losses = []

for i in range(epoch):
    rank_model.zero_grad()
    y_pred = rank_model(doc1, doc2)
    loss = loss_fun(y_pred,y)
    loss.backward()
    optimizer.step()
    losses.append(loss.item())
    #print(y1, y2, y, y_pred)
    
    if i % 100 == 0:
        print('Epoch{}, loss : {}'.format(i, loss.item()))
# Out:
# Epoch0, loss : 0.6910803914070129
# Epoch100, loss : 0.5187612175941467
# Epoch200, loss : 0.5051256418228149
# Epoch300, loss : 0.5003107190132141
# Epoch400, loss : 0.49872085452079773
# Epoch500, loss : 0.4983339011669159
# Epoch600, loss : 0.49863535165786743
# Epoch700, loss : 0.4975854456424713
# Epoch800, loss : 0.4968988299369812
# Epoch900, loss : 0.4981394112110138

# %% [markdown]
# Make predictions for the initial dataset and assign the final cosine similarity to fit feature:

# %%
predScore = []
for job in Data['cleanJobTitle'] :
    embedding = bert_model.encode([job])
    embedding_tensor = torch.from_numpy(embedding).float()
    pred = round(rank_model.predict(embedding_tensor).detach().numpy().sum(),2)
    predScore.append(pred)

Data['fit'] = predScore
Data.sort_values(by ='fit', ascending = False)
# Out:
#                                          cleanJobTitle  \
# id
# 74                         human resource professional
# 10   seeking human resource human resource generali...
# 97                aspiring human resource professional
# 82   aspiring human resource professional  energeti...
# 28                  seeking human resource opportunity
# 27   aspiring human resource management student see...
# 76   aspiring human resource professional  passiona...
# 99                     seeking human resource position
# 73   aspiring human resource manager seeking intern...
# 8                     human resource senior specialist
# 6                   aspiring human resource specialist
# 88                     human resource management major
# 4                  people development coordinator ryan
# 3                 aspiring human resource professional
# 94   seeking human resource opportunity open travel...
# 7    student humber college aspiring human resource...
# 66   experienced retail manager aspiring human reso...
# 68                 human resource specialist luxottica
# 89                          director human resource ey
# 67     human resource staffing recruiting professional
# 101                  human resource generalist loparex
# 98                                             student
# 72   business management major aspiring human resou...
# 84   human resource professional world leader gi so...
# 80                  junior engineer information system
# 78                   human resource generalist schwans
# 92   seeking employment opportunity within customer...
# 103                                 always set success
# 79   liberal art major aspiring human resource analyst
# 71           human resource generalist scottmadden inc
# 1    2019 ct bauer college business graduate magna ...
# 100  aspiring human resource manager  graduating ma...
# 86   information system specialist programmer love ...
# 104         director administration excellence logging
# 102           business intelligence analytics traveler
# 77   human resource conflict management policy  pro...
# 95                  student westfield state university
# 5         advisory board member celal bayar university
# 11                          student chapman university
# 12   svp c human resource marketing  communication ...
# 13   human resource coordinator intercontinental bu...
# 69   director human resource north america groupe b...
# 96   student indiana university kokomo  business ma...
# 83   human resource manager endemol shine north ame...
# 81   senior human resource business partner heil en...
# 93   admission representative community medical cen...
# 75   nortia staffing seeking human resource payroll...
# 91           lead official western illinois university
# 90     undergraduate research assistant styczynski lab
# 2    native english teacher epik english program korea
# 87   bachelor science biology victoria university w...
# 85   rrp brand portfolio executive jti japan tobacc...
# 70   retired army national guard recruiter office m...
#
#                                 location  connection   fit  \
# id
# 74                   Greater Boston Area          16  1.00
# 10             Greater Philadelphia Area         500  1.00
# 97                  Kokomo, Indiana Area          71  1.00
# 82                    Austin, Texas Area         174  1.00
# 28                     Chicago, Illinois         390  1.00
# 27                   Houston, Texas Area         500  1.00
# 76                    New York, New York         212  1.00
# 99                Las Vegas, Nevada Area          48  1.00
# 73                   Houston, Texas Area           7  1.00
# 8                 San Francisco Bay Area         500  1.00
# 6             Greater New York City Area           1  1.00
# 88                  Milpitas, California          18  1.00
# 4                          Denton, Texas         500  1.00
# 3    Raleigh-Durham, North Carolina Area          44  1.00
# 94           Amerika Birleşik Devletleri         415  1.00
# 7                                 Kanada          61  0.99
# 66                    Austin, Texas Area          57  0.99
# 68            Greater New York City Area         500  0.99
# 89                  Greater Atlanta Area         349  0.98
# 67             Jackson, Mississippi Area         500  0.98
# 101  Raleigh-Durham, North Carolina Area         500  0.97
# 98                   Houston, Texas Area           4  0.97
# 72                Monroe, Louisiana Area           5  0.94
# 84                  Highland, California          50  0.77
# 80     Myrtle Beach, South Carolina Area          52  0.73
# 78           Amerika Birleşik Devletleri         500  0.67
# 92                  Torrance, California          64  0.65
# 103             Greater Los Angeles Area         500  0.59
# 79           Baton Rouge, Louisiana Area           7  0.39
# 71   Raleigh-Durham, North Carolina Area         500  0.22
# 1                         Houston, Texas          85  0.16
# 100             Cape Girardeau, Missouri         103  0.05
# 86                Gaithersburg, Maryland           4  0.02
# 104                          Katy, Texas         500  0.01
# 102           Greater New York City Area          49  0.01
# 77                Dallas/Fort Worth Area         409  0.01
# 95            Bridgewater, Massachusetts          57  0.00
# 5                         İzmir, Türkiye         500  0.00
# 11               Lake Forest, California           2  0.00
# 12                   Houston, Texas Area         500  0.00
# 13                      Atlanta, Georgia         500  0.00
# 69   Greater Grand Rapids, Michigan Area         500  0.00
# 96                    Lafayette, Indiana          19  0.00
# 83               Los Angeles, California         268  0.00
# 81           Chattanooga, Tennessee Area         455  0.00
# 93                Long Beach, California           9  0.00
# 75                  San Jose, California         500  0.00
# 91                  Greater Chicago Area          39  0.00
# 90                  Greater Atlanta Area         155  0.00
# 2                                 Kanada         500  0.00
# 87                   Baltimore, Maryland          40  0.00
# 85             Greater Philadelphia Area         500  0.00
# 70              Virginia Beach, Virginia          82  0.00
#
#      BERT_model_fitt_score  starredScore
# id
# 74                0.794618      0.794618
# 10                0.779854      0.779854
# 97                0.930828      0.930828
# 82                0.854400      0.854400
# 28                0.825814      0.825814
# 27                0.703306      0.703306
# 76                0.730179      0.730179
# 99                0.837419      0.837419
# 73                0.759009      0.759009
# 8                 0.745252      0.745252
# 6                 0.950305      0.950305
# 88                0.706733      0.706733
# 4                 0.755497      0.755497
# 3                 0.930828      0.930828
# 94                0.688511      0.688511
# 7                 0.728191      0.728191
# 66                0.651997      0.651997
# 68                0.731514      0.731514
# 89                0.736945      0.736945
# 67                0.721041      0.721041
# 101               0.642743      0.642743
# 98                0.654689      0.654689
# 72                0.633373      0.633373
# 84                0.633590      0.633590
# 80                0.597530      0.597530
# 78                0.623564      0.623564
# 92                0.612518      0.612518
# 103               0.554201      0.554201
# 79                0.575275      0.575275
# 71                0.595474      0.595474
# 1                 0.578465      0.578465
# 100               0.548671      0.548671
# 86                0.526356      0.526356
# 104               0.484158      0.484158
# 102               0.498510      0.498510
# 77                0.514050      0.514050
# 95                0.475011      0.475011
# 5                 0.475463      0.475463
# 11                0.438950      0.438950
# 12                0.472904      0.472904
# 13                0.407859      0.407859
# 69                0.480329      0.480329
# 96                0.252365      0.252365
# 83                0.444863      0.444863
# 81                0.512054      0.512054
# 93                0.192242      0.192242
# 75                0.551570      0.551570
# 91                0.367655      0.367655
# 90                0.470811      0.470811
# 2                 0.411404      0.411404
# 87                0.139689      0.139689
# 85                0.270093      0.270093
# 70                0.477634      0.477634

# %% [markdown]
# ### Conclusion:
#
# BERT model seems to be the best choice for ranking the candidates and to check simillarity between the given query tittles - 'Aspiring human resources' and 'seeking human resources' and the candidates title.
#
# The above table shows the reranking based on the candidate that entered by the user. Candidates with id equal to 3, 74, and 99 were starred for this process.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=409fe3d9-3242-4ff2-a489-9d2975f66a44' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
